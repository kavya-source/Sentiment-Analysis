# %%
from bs4 import BeautifulSoup
import urllib.request
url = 'https://www.trustpilot.com/review/olacabs.com'
ourUrl=urllib.request.urlopen(url)
soup = BeautifulSoup(ourUrl,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script charset="UTF-8" data-domain-script="84cb5c09-05e4-488b-b71c-2fe171dca5e5" data-language="en-US" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="application/javascript">
# </script>
# <script>
#         function OptanonWrapper() {
#             var event = new CustomEvent("OptanonWrapper");
#             document.dispatchEvent(event);
#         }
#     </script>
# <link crossorigin="" href="https://googleads.g.doubleclick.net/" rel="preconnect"/>
# <link crossorigin="" href="https://www.googleadservices.com/" rel="preconnect"/>
# <link crossorigin="" href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.trustpilot.net/" rel="preconnect"/>
# <link crossorigin="" href="https://api.amplitude.com/" rel="preconnect"/>
# <link crossorigin="" href="//user-images.trustpilot.com/" rel="preconnect"/>
# ...

# %%
review=[]
for i in soup.find_all('div',{'class':'review-content'}):
    per_review=i.find('p')
    print(per_review)
    review.append(per_review)
# Out:
# <p class="review-content__text">
#                 Ola advertise 5km for $5.00 what a ripoff from my house to the air port is 4.7 km. The Ola driver arrived<br/>at my house the proceeded to take a long route(a route I have neve used). this route then proved to be in excess of 7km for which I was charged My wfe and i questioned the driver as to where he was going but we were ignored. To top it all the driver was driving at about 80 km/hr in a 50 zone. The nett result is, I  will not use Ola again and bad mouth them at any opportunity I get. I emailed Ola about a week ago to voice my concerns, they have yet to show me the courtesy of a reply. A RIPOFF
#             </p>
# <p class="review-content__text">
#                 Good ola has latest features and with lowest fares
#             </p>
# <p class="review-content__text">
# ...

# %%
len(review)
# Out:
# 20

# %%
url = 'https://www.trustpilot.com/review/olacabs.com?b=MTYyMDQzOTUyOTAwMHw2MDk1ZjFlOWY5ZjQ4NzBhNmNhOTQ1Mjk'
ourUrl=urllib.request.urlopen(url)
soup = BeautifulSoup(ourUrl,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script charset="UTF-8" data-domain-script="84cb5c09-05e4-488b-b71c-2fe171dca5e5" data-language="en-US" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="application/javascript">
# </script>
# <script>
#         function OptanonWrapper() {
#             var event = new CustomEvent("OptanonWrapper");
#             document.dispatchEvent(event);
#         }
#     </script>
# <link crossorigin="" href="https://googleads.g.doubleclick.net/" rel="preconnect"/>
# <link crossorigin="" href="https://www.googleadservices.com/" rel="preconnect"/>
# <link crossorigin="" href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.trustpilot.net/" rel="preconnect"/>
# <link crossorigin="" href="https://api.amplitude.com/" rel="preconnect"/>
# <link crossorigin="" href="//user-images.trustpilot.com/" rel="preconnect"/>
# ...

# %%
for i in soup.find_all('div',{'class':'review-content'}):
    per_review=i.find('p')
    print(per_review)
    review.append(per_review)
# Out:
# <p class="review-content__text">
#                 I booked an Ola cab home with my child and the driver cancelled saying I was not wearing a face mask yet the driver never came to me. The second ride I booked the driver pulled up into the middle of the road blew his horn aggressively and tried to get me to come out into the road while holding a bags, a baby and a scooter. My issue was resolved in real time. I have been trying MONTHS to resolve this with several texts requesting payments for rides I DID NOT TAKE.  Today Ola has charged £15 onto my card. No apology a £15 voucher that disappeared on a £3 ride. Who do I complain to?
#             </p>
# <p class="review-content__text">
# ...

# %%
len(review)
# Out:
# 40

# %%
url = 'https://www.trustpilot.com/review/olacabs.com?b=MTYxODE1ODk3MjAwMHw2MDczMjU3Y2Y4NWQ3NTA4NzA1NWVlMmM'
ourUrl=urllib.request.urlopen(url)
soup = BeautifulSoup(ourUrl,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script charset="UTF-8" data-domain-script="84cb5c09-05e4-488b-b71c-2fe171dca5e5" data-language="en-US" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="application/javascript">
# </script>
# <script>
#         function OptanonWrapper() {
#             var event = new CustomEvent("OptanonWrapper");
#             document.dispatchEvent(event);
#         }
#     </script>
# <link crossorigin="" href="https://googleads.g.doubleclick.net/" rel="preconnect"/>
# <link crossorigin="" href="https://www.googleadservices.com/" rel="preconnect"/>
# <link crossorigin="" href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.trustpilot.net/" rel="preconnect"/>
# <link crossorigin="" href="https://api.amplitude.com/" rel="preconnect"/>
# <link crossorigin="" href="//user-images.trustpilot.com/" rel="preconnect"/>
# ...

# %%
for i in soup.find_all('div',{'class':'review-content'}):
    per_review=i.find('p')
    print(per_review)
    review.append(per_review)
# Out:
# <p class="review-content__text">
#                 Awful company. 20 minutes after signing up and using my account to pay, £161 came out of my bank into a “GoFndMe, Help India” which is obviously a front. Luckily my bank was able to help me, but they also managed to sneak another £162 before my card was cancelled. It was the only thing I have signed up to for weeks, so you cannot tell me it’s just a coincidence.
#             </p>
# <p class="review-content__text">
#                 Very bad service from ola I use it almost everyday and long journeys. Today I took a cab ride which was suppose to take 40 mins but took an 1 hour 10 and wanted to book second drop for my brother to get to work and the driver drove off so my brother was late to work. Driver didn't even know where he was going and driving off after first drop was Completely uncalled for after making my brother late and me late. Worse experience ever. On top of this I lost hours at work. Will demand explanation for this.
# ...

# %%
len(review)
# Out:
# 60

# %%
url = 'https://www.trustpilot.com/review/olacabs.com?b=MTYxNjEyODcxMDAwMHw2MDU0MmFjNmY4NWQ3NTBiZjRmOGFiOWY'
ourUrl=urllib.request.urlopen(url)
soup = BeautifulSoup(ourUrl,'html.parser')
#print(soup.prettify)
for i in soup.find_all('div',{'class':'review-content'}):
    per_review=i.find('p')
    #print(per_review)
    review.append(per_review)
len(review)
# Out:
# 80

# %%
url = 'https://www.trustpilot.com/review/olacabs.com?b=MTYxMzcxMjUzNjAwMHw2MDJmNGM5OGY4NWQ3NTBiOTg5OWRmMzk'
ourUrl=urllib.request.urlopen(url)
soup = BeautifulSoup(ourUrl,'html.parser')
#print(soup.prettify)
for i in soup.find_all('div',{'class':'review-content'}):
    per_review=i.find('p')
    #print(per_review)
    review.append(per_review)
len(review)
# Out:
# 100

# %%
url = 'https://www.trustpilot.com/review/olacabs.com?b=MTYxMTU3NDUyMTAwMHw2MDBlYWNmOTY3OWQ5NzAyODA3ZjBmMTQ'
ourUrl=urllib.request.urlopen(url)
soup = BeautifulSoup(ourUrl,'html.parser')
#print(soup.prettify)
for i in soup.find_all('div',{'class':'review-content'}):
    per_review=i.find('p')
    #print(per_review)
    review.append(per_review)
len(review)
# Out:
# 120

# %%
url = 'https://www.trustpilot.com/review/olacabs.com?b=MTYwOTI5MzUwNDAwMHw1ZmViZGVjMDc1NWRjMTAzMmMwNzExMDg'
ourUrl=urllib.request.urlopen(url)
soup = BeautifulSoup(ourUrl,'html.parser')
#print(soup.prettify)
for i in soup.find_all('div',{'class':'review-content'}):
    per_review=i.find('p')
    #print(per_review)
    review.append(per_review)
len(review)
# Out:
# 140

# %%
URL = ['https://www.trustpilot.com/review/olacabs.com?b=MTYwNzQxNDI2NDAwMHw1ZmNmMzFmODc1NWRjMTA1ZjAyZDQ3OWI','https://www.trustpilot.com/review/olacabs.com?b=MTYwNjAwODE2NTAwMHw1ZmI5YmQ2NTVlNjkzZjA4ZjAwNjdmMGQ','https://www.trustpilot.com/review/olacabs.com?b=MTYwNDUxMzEwMzAwMHw1ZmEyZWQ0ZjVlNjkzZjA2Zjg3OWYyZGU','https://www.trustpilot.com/review/olacabs.com?b=MTYwMjY2NTM0NjAwMHw1Zjg2YmI4Mjc5OGU2ZjBiY2M0NGU4OTg','https://www.trustpilot.com/review/olacabs.com?b=MTYwMDM5NTc2OTAwMHw1ZjY0MTlmOTAyZTg1NzBhNDg3NGI1ZGI','https://www.trustpilot.com/review/olacabs.com?b=MTU5ODgxNTg4ODAwMHw1ZjRiZmU5MDAyZTg1NzA4YzhkYzI4MWU','https://www.trustpilot.com/review/olacabs.com?b=MTU5NzAxMjYwMTAwMHw1ZjMwN2E3OTFhNWE2OTA3ODhhNTQ3M2Y','https://www.trustpilot.com/review/olacabs.com?b=MTU5NDcyNDUzMjAwMHw1ZjBkOTBiNDNmMDZmMjBiYjRiMDZiY2Y','https://www.trustpilot.com/review/olacabs.com?b=MTU5MTM3NzA1MDAwMHw1ZWRhN2M5YTI1ZTVkMjA5YjhmZGVmMTU','https://www.trustpilot.com/review/olacabs.com?b=MTU4NjE0NjM0ODAwMHw1ZThhYWMyYzA4NmI2NDA5NTQzMDc0ODM','https://www.trustpilot.com/review/olacabs.com?b=MTU4Mzk1NTg5NTAwMHw1ZTY5M2ZiNzNjOTNhZTA2MjRjYjQzNDM']
for url in range(0,11):
    ourUrl=urllib.request.urlopen(URL[url])
    soup = BeautifulSoup(ourUrl,'html.parser')
    #print(soup.prettify)
    for i in soup.find_all('div',{'class':'review-content'}):
        per_review=i.find('p')
        #print(per_review)
        review.append(per_review)
len(review)
# Out:
# 580

# %%
f=open("new_reviews.txt","w+", encoding="utf-8")
for each in review:
    new_each=str(each).replace('<br/>','')
    
        
    #new_each=str(each).replace('u"\U0001F600-\U0001F64F"','')
    new_each=new_each[32:-4]
    print(new_each)
    f.write(new_each)
# Out:
#                 Ola advertise 5km for $5.00 what a ripoff from my house to the air port is 4.7 km. The Ola driver arrivedat my house the proceeded to take a long route(a route I have neve used). this route then proved to be in excess of 7km for which I was charged My wfe and i questioned the driver as to where he was going but we were ignored. To top it all the driver was driving at about 80 km/hr in a 50 zone. The nett result is, I  will not use Ola again and bad mouth them at any opportunity I get. I emailed Ola about a week ago to voice my concerns, they have yet to show me the courtesy of a reply. A RIPOFF
#
#
#                 Good ola has latest features and with lowest fares
#
#
#                 Was never picked up waited 5/10min tried to make contact issues using the app.. they deducted $17 from my account which they refunded then charged me $10 for cancellation fee, when i never cancelled useless have deleted the app.
#
#
# ...
